# %% [markdown]
# # Figure 1
#
# Data is a dynamic simulation trajectory (mother machine like) of the deterministic model.

# %%
## imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## loading the data
model_traj = pd.read_csv(filepath_or_buffer="../results-data/dynamic-det-model/trajectory.csv")
model_traj = model_traj.set_index('t')
model_traj.head()
# Out:
#                  A         E         R         Q  U         X    M_or_V  \
# t
# 0.000000  1.000000  1.000000  1.000000  1.000000  0  1.000000  5.000000
# 0.000000  1.000000  1.000000  1.000000  1.000000  0  1.000000  5.000000
# 0.073415  0.868529  1.120664  1.091401  1.189121  0  1.021329  5.291043
# 0.181541  0.688383  1.312537  1.236741  1.489849  0  1.055244  5.782754
# 0.271082  0.562089  1.482212  1.365266  1.755786  0  1.085236  6.250589
#
#                  a         e         r         q         x
# t
# 0.000000  0.200000  0.200000  0.200000  0.200000  0.200000
# 0.000000  0.200000  0.200000  0.200000  0.200000  0.200000
# 0.073415  0.164151  0.211804  0.206273  0.224742  0.193030
# 0.181541  0.119041  0.226974  0.213867  0.257637  0.182481
# 0.271082  0.089926  0.237132  0.218422  0.280899  0.173621

# %%
# seaborn styling options
sns.set(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-cbdaa327ed35> in <module>()
#       1 # seaborn styling options
# ----> 2 sns.set(style="whitegrid")
#
# NameError: name 'sns' is not defined
